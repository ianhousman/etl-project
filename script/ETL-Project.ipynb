# %%
import pandas as pd

# %%
car_sales = "Car_sales.csv"
sales_df = pd.read_csv(car_sales)
sales_df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
car_emissions = "data.csv"
emissions_df = pd.read_csv(car_emissions)
emissions_df.head()
# Out:
#                      file  year manufacturer      model         description  \
# 0  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range  1.6 Twin Spark 16v
# 1  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range  1.8 Twin Spark 16v
# 2  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range          Cloverleaf
# 3  DatapartC_july2000.csv  2000   Alfa Romeo  146 Range  1.6 Twin Spark 16v
# 4  DatapartC_july2000.csv  2000   Alfa Romeo  146 Range  1.8 Twin Spark 16v
#
#    euro_standard tax_band transmission transmission_type  engine_capacity  \
# 0              2      NaN           M5            Manual           1598.0
# 1              2      NaN           M5            Manual           1747.0
# 2              2      NaN           M5            Manual           1970.0
# 3              2      NaN           M5            Manual           1598.0
# 4              2      NaN           M5            Manual           1747.0
#
# ...

# %%
new_sales_df = sales_df[['Manufacturer', 'Sales_in_thousands', 'Fuel_efficiency']].copy()
new_sales_df.head()
# Out:
#   Manufacturer  Sales_in_thousands  Fuel_efficiency
# 0        Acura              16.919             28.0
# 1        Acura              39.384             25.0
# 2        Acura              14.114             26.0
# 3        Acura               8.588             22.0
# 4         Audi              20.397             27.0

# %%
new_emissions_df = emissions_df[['manufacturer', 'co2', 'co_emissions']].copy()
renamed_df = new_emissions_df.rename(columns={'manufacturer': 'Manufacturer', 'co2': 'CO2_Emissions', 'co_emissions': 'CO_Emissions'})
renamed_df.head()
# Out:
#   Manufacturer  CO2_Emissions  CO_Emissions
# 0   Alfa Romeo            195         980.0
# 1   Alfa Romeo            200        1105.0
# 2   Alfa Romeo            210        1103.0
# 3   Alfa Romeo            195         980.0
# 4   Alfa Romeo            200        1105.0

# %%
dropped_sales = new_sales_df.dropna(axis=0)
dropped_emissions = renamed_df.dropna(axis=0)
# Out:
# 45192

# %%
sales_man = dropped_sales['Manufacturer'].unique()
emissions_man = dropped_emi
# Out:
#     Manufacturer  Sales_in_thousands  Fuel_efficiency
# 0          Acura              16.919             28.0
# 1          Acura              39.384             25.0
# 2          Acura              14.114             26.0
# 3          Acura               8.588             22.0
# 4           Audi              20.397             27.0
# ..           ...                 ...              ...
# 151        Volvo              16.957             25.0
# 152        Volvo               3.545             25.0
# 153        Volvo              15.245             25.0
# 154        Volvo              17.531             25.0
# 155        Volvo               3.493             23.0
#
# [121 rows x 3 columns]

# %%
grouped_emissions = dropped_emissions.groupby('Manufacturer')
grouped_emissions.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-c1e359da26f5> in <module>
#       1 grouped_emissions = dropped_emissions.groupby('Manufacturer')
# ----> 2 grouped_emissions.reset_index(inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# ...

# %%
sales_columns = grouped_sales['Manufacturer'].unique()
emissions_columns = grouped_emissions['Manufacturer'].unique()
# Out:
# 30

# %%
merged_df = pd.merge(grouped_sales, grouped_emissions, on='Manufacturer')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-f7a9a30b4c2b> in <module>
# ----> 1 merged_df = pd.merge(grouped_sales, grouped_emissions, on='Manufacturer')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     569         validate=None,
#     570     ):
# --> 571         left = validate_operand(left)
#     572         right = validate_operand(right)
# ...
